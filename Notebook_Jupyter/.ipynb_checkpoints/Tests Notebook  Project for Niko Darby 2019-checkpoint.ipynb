# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke Skywalker = Jedi[0]
ObiWan Kenobi = Jedi[1]
Ahsoka Tano = Jedi[2]
Cal Kestis = Jedi[3]
Emperor Palpatine= Sith[0]
Darth Vadar= Sith[1]
Ventress= Sith[2]
Captain Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi, Sith)
    if Jedi[0]
        return
            print("The Chosen One")
    if Sith[0]
        return
            print("The Dark Side Prevails")
    if Jedi[1]
        return
            print("Hello There!")
    if Sith[1]
        return
            print("Feel the power of the dark side")
    if Jedi[2]
        return
            print("The light is the true path")
    if Sith[2]
        return
            print("Dooku, you traitor!")
    if Jedi[3]
        return
            print("BD-1, thank you")
    if Sith[3]
        return
            print("I am the fancy one")
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").

#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
# Out:
#   File "<ipython-input-1-c5b17af4aaff>", line 18
#     Luke Skywalker = Jedi[0]
#                  ^
# SyntaxError: invalid syntax

# %%
#An error was discovered in the trial above. This is Test #1. I will attempt to fix the error now.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan Kenobi = Jedi[1]
Ahsoka Tano = Jedi[2]
Cal Kestis = Jedi[3]
Emperor Palpatine= Sith[0]
Darth Vadar= Sith[1]
Ventress= Sith[2]
Captain Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi, Sith)
    if Jedi[0]
        return
            print("The Chosen One")
    if Sith[0]
        return
            print("The Dark Side Prevails")
    if Jedi[1]
        return
            print("Hello There!")
    if Sith[1]
        return
            print("Feel the power of the dark side")
    if Jedi[2]
        return
            print("The light is the true path")
    if Sith[2]
        return
            print("Dooku, you traitor!")
    if Jedi[3]
        return
            print("BD-1, thank you")
    if Sith[3]
        return
            print("I am the fancy one")
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").

#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
# Out:
#   File "<ipython-input-3-5363adde7f43>", line 19
#     ObiWan Kenobi = Jedi[1]
#                 ^
# SyntaxError: invalid syntax

# %%
#It seems as though the error is the absence of "_" in each of my executions when defining the names. I will fix this now.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi, Sith)
    if Jedi[0]
        return
            print("The Chosen One")
    if Sith[0]
        return
            print("The Dark Side Prevails")
    if Jedi[1]
        return
            print("Hello There!")
    if Sith[1]
        return
            print("Feel the power of the dark side")
    if Jedi[2]
        return
            print("The light is the true path")
    if Sith[2]
        return
            print("Dooku, you traitor!")
    if Jedi[3]
        return
            print("BD-1, thank you")
    if Sith[3]
        return
            print("I am the fancy one")
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").

#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
# Out:
#   File "<ipython-input-5-befb51c248e8>", line 29
#     def the_balance(Jedi, Sith)
#                                ^
# SyntaxError: invalid syntax

# %%
#Now that the name error has been fixed. I must attempt to fix the function that I created.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi, Sith) : 
    if Jedi[0]
        return
            print("The Chosen One")
    if Sith[0]
        return
            print("The Dark Side Prevails")
    if Jedi[1]
        return
            print("Hello There!")
    if Sith[1]
        return
            print("Feel the power of the dark side")
    if Jedi[2]
        return
            print("The light is the true path")
    if Sith[2]
        return
            print("Dooku, you traitor!")
    if Jedi[3]
        return
            print("BD-1, thank you")
    if Sith[3]
        return
            print("I am the fancy one")
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").

#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
# Out:
#   File "<ipython-input-8-7d4d53e2863d>", line 30
#     if Jedi[0]
#               ^
# SyntaxError: invalid syntax

# %%
# Adding simply a ":" did not seem to work. Maybe a "," after the if statement or a ":" after the if statement will suffice.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi, Sith) : 
    if Jedi[0] : 
        return
            print("The Chosen One")
    if Sith[0] : 
        return
            print("The Dark Side Prevails")
    if Jedi[1] : 
        return
            print("Hello There!")
    if Sith[1] :
        return
            print("Feel the power of the dark side")
    if Jedi[2] :
        return
            print("The light is the true path")
    if Sith[2] :
        return
            print("Dooku, you traitor!")
    if Jedi[3] :
        return
            print("BD-1, thank you")
    if Sith[3] :
        return
            print("I am the fancy one")
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").

#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
# Out:
#   File "<ipython-input-10-76ceb785206b>", line 32
#     print("The Chosen One")
#     ^
# IndentationError: unexpected indent

# %%
#The ":" worked to fix the if-statements, however, as suspected, there needs to be a proper indentation for the print statements in the if statements.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi, Sith) : 
    if Jedi[0] : 
        return
    print("The Chosen One")
    if Sith[0] : 
        return
    print("The Dark Side Prevails")
    if Jedi[1] : 
        return
    print("Hello There!")
    if Sith[1] :
        return
    print("Feel the power of the dark side")
    if Jedi[2] :
        return
    print("The light is the true path")
    if Sith[2] :
        return
    print("Dooku, you traitor!")
    if Jedi[3] :
        return
    print("BD-1, thank you")
    if Sith[3] :
        return
    print("I am the fancy one")
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").

#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.

# %%
#Bravo! My code worked thus far. Now I must run a few tests. Be back sooN!

# %%
#Now I have to test my functions performance abilities.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi, Sith) : 
    if Jedi[0] : 
        return
    print("The Chosen One")
    if Sith[0] : 
        return
    print("The Dark Side Prevails")
    if Jedi[1] : 
        return
    print("Hello There!")
    if Sith[1] :
        return
    print("Feel the power of the dark side")
    if Jedi[2] :
        return
    print("The light is the true path")
    if Sith[2] :
        return
    print("Dooku, you traitor!")
    if Jedi[3] :
        return
    print("BD-1, thank you")
    if Sith[3] :
        return
    print("I am the fancy one")
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance(Luke_Skywalker)
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
Print(Interogation_2)
#Now print your answer below using the_balance("your choice").
the_balance(Ahsoka_Tano)
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-e5ea6faec304> in <module>
#      58 #Now print your answer below using the_balance("your choice").
#      59 #Here is my sample answer:
# ---> 60 the_balance(Luke_Skywalker)
#      61 #It is now time for the next question.
#      62 Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#
# TypeError: the_balance() missing 1 required positional argument: 'Sith'

# %%
#Intriguing, I did not complete my function. I will see what it yields on the next run.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi, Sith) : 
    if Jedi[0] : 
        return
    print("The Chosen One")
    if Sith[0] : 
        return
    print("The Dark Side Prevails")
    if Jedi[1] : 
        return
    print("Hello There!")
    if Sith[1] :
        return
    print("Feel the power of the dark side")
    if Jedi[2] :
        return
    print("The light is the true path")
    if Sith[2] :
        return
    print("Dooku, you traitor!")
    if Jedi[3] :
        return
    print("BD-1, thank you")
    if Sith[3] :
        return
    print("I am the fancy one")
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance(Luke_Skywalker, Emperor_Palpatine)
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
Print(Interogation_2)
#Now print your answer below using the_balance("your choice").
the_balance(Ahsoka_Tano, Ventress)
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-e9956ca60aa9> in <module>
#      61 #It is now time for the next question.
#      62 Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
# ---> 63 Print(Interogation_2)
#      64 #Now print your answer below using the_balance("your choice").
#      65 the_balance(Ahsoka_Tano, Ventress)
#
# NameError: name 'Print' is not defined

# %%
#Slight typo, I will make the edit now.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi, Sith) : 
    if Jedi[0] : 
        return
    print("The Chosen One")
    if Sith[0] : 
        return
    print("The Dark Side Prevails")
    if Jedi[1] : 
        return
    print("Hello There!")
    if Sith[1] :
        return
    print("Feel the power of the dark side")
    if Jedi[2] :
        return
    print("The light is the true path")
    if Sith[2] :
        return
    print("Dooku, you traitor!")
    if Jedi[3] :
        return
    print("BD-1, thank you")
    if Sith[3] :
        return
    print("I am the fancy one")
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance(Luke_Skywalker, Emperor_Palpatine)
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interogation_2)
#Now print your answer below using the_balance("your choice").
the_balance(Ahsoka_Tano, Ventress)
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-7af5867991b1> in <module>
#      61 #It is now time for the next question.
#      62 Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
# ---> 63 print(Interogation_2)
#      64 #Now print your answer below using the_balance("your choice").
#      65 the_balance(Ahsoka_Tano, Ventress)
#
# NameError: name 'Interogation_2' is not defined

# %%
#Another typo, I will make the edit now.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi, Sith) : 
    if Jedi[0] : 
        return
    print("The Chosen One")
    if Sith[0] : 
        return
    print("The Dark Side Prevails")
    if Jedi[1] : 
        return
    print("Hello There!")
    if Sith[1] :
        return
    print("Feel the power of the dark side")
    if Jedi[2] :
        return
    print("The light is the true path")
    if Sith[2] :
        return
    print("Dooku, you traitor!")
    if Jedi[3] :
        return
    print("BD-1, thank you")
    if Sith[3] :
        return
    print("I am the fancy one")
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance(Luke_Skywalker, Emperor_Palpatine)
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
the_balance(Ahsoka_Tano, Ventress)
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar.

# %%
#The code and functions are working. I just need to "print" my answers.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi, Sith) : 
    if Jedi[0] : 
        return
    print("The Chosen One")
    if Sith[0] : 
        return
    print("The Dark Side Prevails")
    if Jedi[1] : 
        return
    print("Hello There!")
    if Sith[1] :
        return
    print("Feel the power of the dark side")
    if Jedi[2] :
        return
    print("The light is the true path")
    if Sith[2] :
        return
    print("Dooku, you traitor!")
    if Jedi[3] :
        return
    print("BD-1, thank you")
    if Sith[3] :
        return
    print("I am the fancy one")
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
print(the_balance(Luke_Skywalker, Emperor_Palpatine))
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
print(the_balance(Ahsoka_Tano, Ventress))
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# None
# Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar.
# None

# %%
#For some reason, I am receiving the "none" error. I need to fix this.

# %%
#I discovered that I am getting the "none" error due to there being TWO print statements. The one from my function and the one from my insertion of "print". I eradicated my insertion of print and I also eradicated the print in my function and simpluy inserted the quotation after the "return" value.

# %%
#See below:

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi, Sith) : 
    if Jedi[0] : 
        return "The Chosen One"
    if Sith[0] : 
        return "The Dark Side Prevails"
    if Jedi[1] : 
        return "Hello There!"
    if Sith[1] :
        return "Feel the power of the dark side"
    if Jedi[2] :
        return "The light is the true path"
    if Sith[2] :
        return "Dooku, you traitor!"
    if Jedi[3] :
        return "BD-1, thank you"
    if Sith[3] :
        return "I am the fancy one"
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance(Luke_Skywalker, Emperor_Palpatine)
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
the_balance(Ahsoka_Tano, Ventress)
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar.
# 'The Chosen One'

# %%
#Strangely, I only received on output. I will try to fix this.

# %%
# I erased the Sith name from the sample answers and instead of having the_balance(Jedi, Sith) for my function, I now have the_balance(Jedi or Sith). Let us see if it works.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi or Sith) : 
    if Jedi[0] : 
        return "The Chosen One"
    if Sith[0] : 
        return "The Dark Side Prevails"
    if Jedi[1] : 
        return "Hello There!"
    if Sith[1] :
        return "Feel the power of the dark side"
    if Jedi[2] :
        return "The light is the true path"
    if Sith[2] :
        return "Dooku, you traitor!"
    if Jedi[3] :
        return "BD-1, thank you"
    if Sith[3] :
        return "I am the fancy one"
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance(Luke_Skywalker)
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
the_balance(Ahsoka_Tano)
# Out:
#   File "<ipython-input-30-5a287dfc6104>", line 29
#     def the_balance(Jedi or Sith) :
#                           ^
# SyntaxError: invalid syntax

# %%
# The "or" causes a Syntax error

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi , Sith) : 
    if Jedi[0] : 
        return "The Chosen One"
    if Sith[0] : 
        return "The Dark Side Prevails"
    if Jedi[1] : 
        return "Hello There!"
    if Sith[1] :
        return "Feel the power of the dark side"
    if Jedi[2] :
        return "The light is the true path"
    if Sith[2] :
        return "Dooku, you traitor!"
    if Jedi[3] :
        return "BD-1, thank you"
    if Sith[3] :
        return "I am the fancy one"
    if Jedi[0] and Sith[0] : 
        return "You have chosen the wrong path" 
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance(Luke_Skywalker, Emperor_Palpatine)
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
the_balance(Ahsoka_Tano, Ventress)
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar.
# 'The Chosen One'

# %%
#I attempted to add to the function the following "If Jedi[0] and Sith[0] (under this) return "You have chosen the wrong path" this technique failed as well. I will continue troubleshooting.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi , Sith) : 
    if Jedi[0] : 
        return "The Chosen One"
    if Sith[0] : 
        return "The Dark Side Prevails"
    if Jedi[1] : 
        return "Hello There!"
    if Sith[1] :
        return "Feel the power of the dark side"
    if Jedi[2] :
        return "The light is the true path"
    if Sith[2] :
        return "Dooku, you traitor!"
    if Jedi[3] :
        return "BD-1, thank you"
    if Sith[3] :
        return "I am the fancy one"
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
print(the_balance(Luke_Skywalker, Emperor_Palpatine))
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
print(the_balance(Ahsoka_Tano, Ventress))
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# The Chosen One
# Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar.
# The Chosen One

# %%
#Yet again I am encountering the bug of receiving the same output "The Chosen One", now matter my input. Let's try replacing some "if"s with "elif".

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi , Sith) : 
    if Jedi[0] : 
        return "The Chosen One"
    elif Sith[0] : 
        return "The Dark Side Prevails"
    elif Jedi[1] : 
        return "Hello There!"
    elif Sith[1] :
        return "Feel the power of the dark side"
    elif Jedi[2] :
        return "The light is the true path"
    elif Sith[2] :
        return "Dooku, you traitor!"
    elif Jedi[3] :
        return "BD-1, thank you"
    elif Sith[3] :
        return "I am the fancy one"
    else :
        return "YOU HAVE FAILED ME!!" 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
print(the_balance(Luke_Skywalker, Emperor_Palpatine))
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
print(the_balance(Ahsoka_Tano, Ventress))
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# The Chosen One
# Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar.
# The Chosen One

# %%
#I decided to alter each return statement to a print statement. Let us see if this works.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi , Sith) : 
    if Jedi[0] : 
        print("The Chosen One")
    elif Sith[0] : 
        print("The Dark Side Prevails")
    elif Jedi[1] : 
        print("Hello There!")
    elif Sith[1] :
        print("Feel the power of the dark side")
    elif Jedi[2] :
        print("The light is the true path")
    elif Sith[2] :
        print("Dooku, you traitor!")
    elif Jedi[3] :
        print("BD-1, thank you")
    elif Sith[3] :
        print("I am the fancy one")
    else :
        print("YOU HAVE FAILED ME!!") 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
print(the_balance(Luke_Skywalker, Emperor_Palpatine))
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
print(the_balance(Ahsoka_Tano, Ventress))
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# The Chosen One
# None
# Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar.
# The Chosen One
# None

# %%
#This time I altered all of the "elifs" to "if". Testing...

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi , Sith) : 
    if Jedi[0] : 
        print("The Chosen One")
    if Sith[0] : 
        print("The Dark Side Prevails")
    if Jedi[1] : 
        print("Hello There!")
    if Sith[1] :
        print("Feel the power of the dark side")
    if Jedi[2] :
        print("The light is the true path")
    if Sith[2] :
        print("Dooku, you traitor!")
    if Jedi[3] :
        print("BD-1, thank you")
    if Sith[3] :
        print("I am the fancy one")
    else :
        print("YOU HAVE FAILED ME!!") 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
print(the_balance(Luke_Skywalker, Emperor_Palpatine))
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
print(the_balance(Ahsoka_Tano, Ventress))
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# The Chosen One
# The Dark Side Prevails
# Hello There!
# Feel the power of the dark side
# The light is the true path
# Dooku, you traitor!
# BD-1, thank you
# I am the fancy one
# None
# Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar.
# The Chosen One
# The Dark Side Prevails
# Hello There!
# Feel the power of the dark side
# The light is the true path
# Dooku, you traitor!
# BD-1, thank you
# I am the fancy one
# None

# %%
#Doing that provided me with all of the options. Not good. Let's try the inverse and change the proceeding "ifs" to "else"

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi , Sith) : 
    if Jedi[0] : 
        print("The Chosen One")
    else Sith[0] : 
        print("The Dark Side Prevails")
    else Jedi[1] : 
        print("Hello There!")
    else Sith[1] :
        print("Feel the power of the dark side")
    else Jedi[2] :
        print("The light is the true path")
    else Sith[2] :
        print("Dooku, you traitor!")
    else Jedi[3] :
        print("BD-1, thank you")
    else Sith[3] :
        print("I am the fancy one")
    else :
        print("YOU HAVE FAILED ME!!") 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
print(the_balance(Luke_Skywalker, Emperor_Palpatine))
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
print(the_balance(Ahsoka_Tano, Ventress))
# Out:
#   File "<ipython-input-42-b23356157e53>", line 32
#     else Sith[0] :
#             ^
# SyntaxError: invalid syntax

# %%
#Not good, I received a SyntaxError when using "else". Time to eradicate all values proceeding the first "if" and see what happens.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi , Sith) : 
    if Jedi[0] : 
        print("The Chosen One")
        Sith[0] : 
        print("The Dark Side Prevails")
        Jedi[1] : 
        print("Hello There!")
        Sith[1] :
        print("Feel the power of the dark side")
        Jedi[2] :
        print("The light is the true path")
        Sith[2] :
        print("Dooku, you traitor!")
        Jedi[3] :
        print("BD-1, thank you")
        Sith[3] :
        print("I am the fancy one")
    else :
        print("YOU HAVE FAILED ME!!") 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
print(the_balance(Luke_Skywalker, Emperor_Palpatine))
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
print(the_balance(Ahsoka_Tano, Ventress))
# Out:
#   File "<ipython-input-44-9da76130c9d4>", line 32
#     Sith[0] :
#               ^
# SyntaxError: invalid syntax

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi , Sith) : 
    if Jedi[0] : 
        print("The Chosen One")
    if Sith[0] : 
        print("The Dark Side Prevails")
    if Jedi[1] : 
        print("Hello There!")
    if Sith[1] :
        print("Feel the power of the dark side")
    if Jedi[2] :
        print("The light is the true path")
    if Sith[2] :
        print("Dooku, you traitor!")
    if Jedi[3] :
        print("BD-1, thank you")
    if Sith[3] :
        print("I am the fancy one")
    else :
        print("YOU HAVE FAILED ME!!") 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance(Luke_Skywalker, Emperor_Palpatine)
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
the_balance(Ahsoka_Tano, Ventress)
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# The Chosen One
# The Dark Side Prevails
# Hello There!
# Feel the power of the dark side
# The light is the true path
# Dooku, you traitor!
# BD-1, thank you
# I am the fancy one
# Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar.
# The Chosen One
# The Dark Side Prevails
# Hello There!
# Feel the power of the dark side
# The light is the true path
# Dooku, you traitor!
# BD-1, thank you
# I am the fancy one

# %%
#As a result of the continued bugs, I decided to re-hash the function. I deleted the args from the original function and turned it into "the_balance()" and then I set it equal to the first Interrogation question. The answer to such should yield a quote.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.")
    if Interrogation_1 == Jedi[0] : 
        print("The Chosen One")
    if Interrogation_1 == Sith[0] : 
        print("The Dark Side Prevails")
    if Interrogation_1 == Jedi[1] : 
        print("Hello There!")
    if Interrogation_1 == Sith[1] :
        print("Feel the power of the dark side")
    if Interrogation_1 == Jedi[2] :
        print("The light is the true path")
    if Interrogation_1 == Sith[2] :
        print("Dooku, you traitor!")
    if Interrogation_1 == Jedi[3] :
        print("BD-1, thank you")
    if Interrogation_1 == Sith[3] :
        print("I am the fancy one")
    else :
        print("YOU HAVE FAILED ME!!") 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance(Luke_Skywalker)
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
the_balance(Ahsoka_Tano)
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-09548a297e7e> in <module>
#      54 #Now print your answer below using the_balance("your choice").
#      55 #Here is my sample answer:
# ---> 56 the_balance(Luke_Skywalker)
#      57 #It is now time for the next question.
#      58 Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#
# TypeError: the_balance() takes 0 positional arguments but 1 was given

# %%
#Accidentally provided an arg, let's see what happens when we set the function equal to something.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.")
    if Interrogation_1 == Jedi[0] : 
        print("The Chosen One")
    if Interrogation_1 == Sith[0] : 
        print("The Dark Side Prevails")
    if Interrogation_1 == Jedi[1] : 
        print("Hello There!")
    if Interrogation_1 == Sith[1] :
        print("Feel the power of the dark side")
    if Interrogation_1 == Jedi[2] :
        print("The light is the true path")
    if Interrogation_1 == Sith[2] :
        print("Dooku, you traitor!")
    if Interrogation_1 == Jedi[3] :
        print("BD-1, thank you")
    if Interrogation_1 == Sith[3] :
        print("I am the fancy one")
    else :
        print("YOU HAVE FAILED ME!!") 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance() == Luke_Skywalker
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
the_balance()== Ahsoka_Tano
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Luke_Skywalker
# YOU HAVE FAILED ME!!
# Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar.
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.ObiWan_Kenobi
# YOU HAVE FAILED ME!!
# False

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.")
    if Interrogation_1 == Jedi[0] : 
        print("The Chosen One")
    if Interrogation_1 == Sith[0] : 
        print("The Dark Side Prevails")
    if Interrogation_1 == Jedi[1] : 
        print("Hello There!")
    if Interrogation_1 == Sith[1] :
        print("Feel the power of the dark side")
    if Interrogation_1 == Jedi[2] :
        print("The light is the true path")
    if Interrogation_1 == Sith[2] :
        print("Dooku, you traitor!")
    if Interrogation_1 == Jedi[3] :
        print("BD-1, thank you")
    if Interrogation_1 == Sith[3] :
        print("I am the fancy one")
    else :
        print("YOU HAVE FAILED ME!!") 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance() == Luke_Skywalker
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
the_balance()== Ahsoka_Tano
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Jedi[0]
# YOU HAVE FAILED ME!!
# Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar.
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Interrogation_1
# YOU HAVE FAILED ME!!
# False

# %%
# I constructed an answer choice slot. Now I have to edit the code so that whatever answer you input provides a quote.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.")
    if Interrogation_1 == Jedi[0] : 
        print("The Chosen One")
    if Interrogation_1 == Sith[0] : 
        print("The Dark Side Prevails")
    if Interrogation_1 == Jedi[1] : 
        print("Hello There!")
    if Interrogation_1 == Sith[1] :
        print("Feel the power of the dark side")
    if Interrogation_1 == Jedi[2] :
        print("The light is the true path")
    if Interrogation_1 == Sith[2] :
        print("Dooku, you traitor!")
    if Interrogation_1 == Jedi[3] :
        print("BD-1, thank you")
    if Interrogation_1 == Sith[3] :
        print("I am the fancy one")
    else :
        print("YOU HAVE FAILED ME!!") 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance()
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Luke_Skywalker
# YOU HAVE FAILED ME!!
# Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar.
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Ventress
# Dooku, you traitor!
# YOU HAVE FAILED ME!!

# %%
#Deleting the "==" did not assist with the proper answer choices. I will have to troubleshoot some more.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.")
    if Interrogation_1 == Jedi[0] : 
        print("The Chosen One")
    if Interrogation_1 == Sith[0] : 
        print("The Dark Side Prevails")
    if Interrogation_1 == Jedi[1] : 
        print("Hello There!")
    if Interrogation_1 == Sith[1] :
        print("Feel the power of the dark side")
    if Interrogation_1 == Jedi[2] :
        print("The light is the true path")
    if Interrogation_1 == Sith[2] :
        print("Dooku, you traitor!")
    if Interrogation_1 == Jedi[3] :
        print("BD-1, thank you")
    if Interrogation_1 == Sith[3] :
        print("I am the fancy one")
    else :
        print("YOU HAVE FAILED ME!!") 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance()
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Jedi[0]
# YOU HAVE FAILED ME!!
# Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar.
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Cal_Kestis
# YOU HAVE FAILED ME!!

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.")
    if  Interrogation_1 == Luke_Skywalker : 
        print("The Chosen One")
    if Interrogation_1 == Emperor_Palpatine : 
        print("The Dark Side Prevails")
    if Interrogation_1 == ObiWan_Kenobi : 
        print("Hello There!")
    if Interrogation_1 == Darth_Vadar :
        print("Feel the power of the dark side")
    if Interrogation_1 == Ahsoka_Tano :
        print("The light is the true path")
    if Interrogation_1 == Ventress :
        print("Dooku, you traitor!")
    if Interrogation_1 == Cal_Kestis :
        print("BD-1, thank you")
    if Interrogation_1 == Captain_Phasma :
        print("I am the fancy one")
    else :
        print("YOU HAVE FAILED ME!!") 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance() 
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Luke_Skywalker
# YOU HAVE FAILED ME!!
# Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar.
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Ahsoka_Tano
# YOU HAVE FAILED ME!!

# %%
#Trial2

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.")
    if  Interrogation_1 == Luke_Skywalker : 
        print("The Chosen One")
    if Interrogation_1 == Emperor_Palpatine : 
        print("The Dark Side Prevails")
    if Interrogation_1 == ObiWan_Kenobi : 
        print("Hello There!")
    if Interrogation_1 == Darth_Vadar :
        print("Feel the power of the dark side")
    if Interrogation_1 == Ahsoka_Tano :
        print("The light is the true path")
    if Interrogation_1 == Ventress :
        print("Dooku, you traitor!")
    if Interrogation_1 == Cal_Kestis :
        print("BD-1, thank you")
    if Interrogation_1 == Captain_Phasma :
        print("I am the fancy one")
    else :
        print("YOU HAVE FAILED ME!!") 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
print(Interrogation_1)
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance() 
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
print(Interrogation_2)
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Interrogation_1 == Luke_Skywalker
# YOU HAVE FAILED ME!!
# Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar.
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Interrogation_1
# YOU HAVE FAILED ME!!

# %%
#More failures in procuring a proper answer. I will try to fix this once more.

# %%
#This will be a quick test by erasing the "Interrogation_1 == Luke_Skywalker" in the function and just keeping "Luke_Skywalker"

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.")
    if  Luke_Skywalker : 
        print("The Chosen One")
    if Interrogation_1 == Emperor_Palpatine : 
        print("The Dark Side Prevails")
    if Interrogation_1 == ObiWan_Kenobi : 
        print("Hello There!")
    if Interrogation_1 == Darth_Vadar :
        print("Feel the power of the dark side")
    if Interrogation_1 == Ahsoka_Tano :
        print("The light is the true path")
    if Interrogation_1 == Ventress :
        print("Dooku, you traitor!")
    if Interrogation_1 == Cal_Kestis :
        print("BD-1, thank you")
    if Interrogation_1 == Captain_Phasma :
        print("I am the fancy one")
    else :
        print("YOU HAVE FAILED ME!!") 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance() 
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Luke_Skywalker
# The Chosen One
# YOU HAVE FAILED ME!!
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Emperor_Palpatine
# The Chosen One
# YOU HAVE FAILED ME!!

# %%
#An answer was yielded. Now let's remove the "==" from everything in the code and try again with some slight edits.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.")
    if  Luke_Skywalker : 
        print("The Chosen One")
    if Emperor_Palpatine : 
        print("The Dark Side Prevails")
    if ObiWan_Kenobi : 
        print("Hello There!")
    if Darth_Vadar :
        print("Feel the power of the dark side")
    if Ahsoka_Tano :
        print("The light is the true path")
    if Ventress :
        print("Dooku, you traitor!")
    if Cal_Kestis :
        print("BD-1, thank you")
    if Captain_Phasma :
        print("I am the fancy one")
    else :
        print("You have chosen your destiny. Continue young one.") 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance() 
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Emperor Palpatine
# The Chosen One
# The Dark Side Prevails
# Hello There!
# Feel the power of the dark side
# The light is the true path
# Dooku, you traitor!
# BD-1, thank you
# I am the fancy one
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Darth_Vadar
# The Chosen One
# The Dark Side Prevails
# Hello There!
# Feel the power of the dark side
# The light is the true path
# Dooku, you traitor!
# BD-1, thank you
# I am the fancy one

# %%
#Let's try using "elif" instead of a bunch of "ifs".

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.")
    if  Luke_Skywalker : 
        print("The Chosen One")
    elif Emperor_Palpatine : 
        print("The Dark Side Prevails")
    elif ObiWan_Kenobi : 
        print("Hello There!")
    elif Darth_Vadar :
        print("Feel the power of the dark side")
    elif Ahsoka_Tano :
        print("The light is the true path")
    elif Ventress :
        print("Dooku, you traitor!")
    elif Cal_Kestis :
        print("BD-1, thank you")
    elif Captain_Phasma :
        print("I am the fancy one")
    else :
        print("You have chosen your destiny. Continue young one.") 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance() 
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Luke_Skywalker
# The Chosen One
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Darth_Vadar
# The Chosen One

# %%
# Another test

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.")
    if  Luke_Skywalker : 
        print("The Chosen One")
    elif Emperor_Palpatine : 
        print("The Dark Side Prevails")
    if ObiWan_Kenobi : 
        print("Hello There!")
    elif Darth_Vadar :
        print("Feel the power of the dark side")
    if Ahsoka_Tano :
        print("The light is the true path")
    elif Ventress :
        print("Dooku, you traitor!")
    if Cal_Kestis :
        print("BD-1, thank you")
    elif Captain_Phasma :
        print("I am the fancy one")
    else :
        print("You have chosen your destiny. Continue young one.") 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance() 
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.ObiWan_Kenobi
# The Chosen One
# Hello There!
# The light is the true path
# BD-1, thank you
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.Darth_Vadar
# The Chosen One
# Hello There!
# The light is the true path
# BD-1, thank you

# %%
#All "elifs" are ignored. This is ominous. I will have to attempt another test.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar.")
    else:  Luke_Skywalker : 
        print("The Chosen One")
    else: Emperor_Palpatine : 
        print("The Dark Side Prevails")
    if ObiWan_Kenobi : 
        print("Hello There!")
    elif Darth_Vadar :
        print("Feel the power of the dark side")
    if Ahsoka_Tano :
        print("The light is the true path")
    elif Ventress :
        print("Dooku, you traitor!")
    if Cal_Kestis :
        print("BD-1, thank you")
    elif Captain_Phasma :
        print("I am the fancy one")
    else :
        print("You have chosen your destiny. Continue young one.") 
    
        
#Since the function "the_balance(Jedi,Sith)" is now created. The rest of the code can be concocted. 
Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker and Obi-Wan Kenobi for the Jedi. For the Sith, choose between Emperor Palpatine or Darth Vadar."
#Now print your answer below using the_balance("your choice").
#Here is my sample answer: 
the_balance() 
#It is now time for the next question. 
Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
#   File "<ipython-input-68-d6867d746a59>", line 31
#     else:  Luke_Skywalker :
#        ^
# SyntaxError: invalid syntax

# %%
#I deleted a few lines but let's try this:

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.")
    if  Luke_Skywalker : 
        print("The Chosen One")
    else : 
        print("The Dark Side Prevails")
    
        
#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 

Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.Luke_Skywalker
# The Chosen One
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.Emperor Palpatine
# The Chosen One

# %%
#Re-try

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.")
    if  Luke_Skywalker : 
        print("The Chosen One")
    else : 
        print("The Dark Side Prevails")
    
        
#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 

Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.Emperor_Palpatine
# The Chosen One
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.Luke_Skywalker
# The Chosen One

# %%
# Another test with slight functional edit.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi) :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.")
    if  Luke_Skywalker : 
        print("The Chosen One")
    else : 
        print("The Dark Side Prevails")
    
        
#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 

Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-d087ee3cae1d> in <module>
#      39 #Here is my sample answer:
#      40
# ---> 41 the_balance()
#      42
#      43 #It is now time for the next question.
#
# TypeError: the_balance() missing 1 required positional argument: 'Jedi'

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance(Jedi, Sith) :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.")
    if  Luke_Skywalker : 
        print("The Chosen One")
    if Emperor_Palpatine :  
        print("The Dark Side Prevails")
    if ObiWan_Kenobi : 
        print("Hello There!")
    if Darth_Vadar :
        print("Feel the power of the dark side")
    if Ahsoka_Tano :
        print("The light is the true path")
    if Ventress :
        print("Dooku, you traitor!")
    if Cal_Kestis :
        print("BD-1, thank you")
    if Captain_Phasma :
        print("I am the fancy one")
    else :
        print("You have chosen your destiny. Continue young one.") 

    
        
#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance(Luke_Skywalker, Emperor_Palpatine) 

#It is now time for the next question. 

Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
the_balance(Ahsoka_Tano, Ventress)
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.Emperor_Palpatine
# The Chosen One
# The Dark Side Prevails
# Hello There!
# Feel the power of the dark side
# The light is the true path
# Dooku, you traitor!
# BD-1, thank you
# I am the fancy one
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.ahji
# The Chosen One
# The Dark Side Prevails
# Hello There!
# Feel the power of the dark side
# The light is the true path
# Dooku, you traitor!
# BD-1, thank you
# I am the fancy one

# %%
# Still editing.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.")
    if  Luke_Skywalker : 
        print("The Chosen One")
    if Emperor_Palpatine :  
        print("The Dark Side Prevails")
    if ObiWan_Kenobi : 
        print("Hello There!")
    if Darth_Vadar :
        print("Feel the power of the dark side")
    if Ahsoka_Tano :
        print("The light is the true path")
    if Ventress :
        print("Dooku, you traitor!")
    if Cal_Kestis :
        print("BD-1, thank you")
    if Captain_Phasma :
        print("I am the fancy one")
    else :
        print("You have chosen your destiny. Continue young one.") 

    
        
#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 

Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.Emperor_Palpatine
# The Chosen One
# The Dark Side Prevails
# Hello There!
# Feel the power of the dark side
# The light is the true path
# Dooku, you traitor!
# BD-1, thank you
# I am the fancy one
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.l
# The Chosen One
# The Dark Side Prevails
# Hello There!
# Feel the power of the dark side
# The light is the true path
# Dooku, you traitor!
# BD-1, thank you
# I am the fancy one

# %%
#It seems as though no matter what answer I put, I always get the same results.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = "Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith."
    if  Interrogation_1 == Luke_Skywalker : 
        print("The Chosen One")
    else :  
        print("The Dark Side Prevails")
        
#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 

Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# The Dark Side Prevails
# The Dark Side Prevails

# %%
# Let's try replacing "print" with "return" in the function to see what happens when I input an answer.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.")
    if  Interrogation_1 == Luke_Skywalker : 
        return "The Chosen One"
    if ObiWan_Kenobi : 
        return "Hello There!"
    if Darth_Vadar :
        return "Feel the power of the dark side"
    if Ahsoka_Tano :
        return "The light is the true path"
    if Ventress :
        return "Dooku, you traitor!"
    if Cal_Kestis :
        return "BD-1, thank you"
    if Captain_Phasma :
        return "I am the fancy one"
    else :
        return "You have chosen your destiny. Continue young one." 
    

        
#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 

Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.Luke_Skywalker
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.Emperor_Palpatine
# 'Hello There!'

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.")
    if  Luke_Skywalker : 
        return "The Chosen One"
    if Emperor_Palpatine : 
        return "The Dark Side Prevails"
    if ObiWan_Kenobi : 
        return "Hello There!"
    if Darth_Vadar :
        return "Feel the power of the dark side"
    if Ahsoka_Tano :
        return "The light is the true path"
    if Ventress :
        return "Dooku, you traitor!"
    if Cal_Kestis :
        return "BD-1, thank you"
    if Captain_Phasma :
        return "I am the fancy one"
    else :
        return "You have chosen your destiny. Continue young one." 
    

        
#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 

Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.Emperor_Palpatine
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.ObiWan_Kenobi
# 'The Chosen One'

# %%
# Another test

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.")
    if  Interrogation_1 == "Tester_1" : 
        return "The Chosen One"
    if Interrogation_1 == "Tester_2" : 
        return "The Dark Side Prevails"
    if ObiWan_Kenobi : 
        return "Hello There!"
    if Darth_Vadar :
        return "Feel the power of the dark side"
    if Ahsoka_Tano :
        return "The light is the true path"
    if Ventress :
        return "Dooku, you traitor!"
    if Cal_Kestis :
        return "BD-1, thank you"
    if Captain_Phasma :
        return "I am the fancy one"
    else :
        return "You have chosen your destiny. Continue young one." 
    

        
#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 

Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith."Tester_2"
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith."Tester_1"
# 'Hello There!'

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.")
    if  Interrogation_1 == "Tester_1" : 
        print("The Chosen One")
    if Interrogation_1 == "Tester_2" : 
        print("The Dark Side Prevails")
    if ObiWan_Kenobi : 
        return "Hello There!"
    if Darth_Vadar :
        return "Feel the power of the dark side"
    if Ahsoka_Tano :
        return "The light is the true path"
    if Ventress :
        return "Dooku, you traitor!"
    if Cal_Kestis :
        return "BD-1, thank you"
    if Captain_Phasma :
        return "I am the fancy one"
    else :
        return "You have chosen your destiny. Continue young one." 
    

        
#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 

Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.Tester_1
# The Chosen One
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.Tester_2
# The Dark Side Prevails
# 'Hello There!'

# %%
# We got it to work with the testers! Hooray, now let's try with all answers available.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.")
    if  Interrogation_1 == "Luke Skywalker" : 
        print("The Chosen One")
    if Interrogation_1 == "Emperor Palpatine" : 
        print("The Dark Side Prevails")
    if Interrogation_1 == "Obi-Wan Kenobi" : 
        return "Hello There!"
    if Interrogation_1 == "Darth Vadar" :
        return "Feel the power of the dark side"
    if Interrogation_1 == "Ahsoka Tano" :
        return "The light is the true path"
    if Interrogation_1 == "Ventress" :
        return "Dooku, you traitor!"
    if Interrogation_1 == "Cal_Kestis" :
        return "BD-1, thank you"
    if Interrogation_1 == Captain_Phasma :
        return "I am the fancy one"
    else :
        return "You have chosen your destiny. Continue young one." 
    

        
#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 

Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.Emperor Palpatine
# The Dark Side Prevails
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.Ahsoka Tano
# 'The light is the true path'

# %%
# One more test

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.")
    if  Interrogation_1 == "Luke Skywalker" : 
        print("The Chosen One")
    if Interrogation_1 == "Emperor Palpatine" : 
        print("The Dark Side Prevails")
    if Interrogation_1 == "Obi-Wan Kenobi" : 
        return "Hello There!"
    if Interrogation_1 == "Darth Vadar" :
        return "Feel the power of the dark side"
    if Interrogation_1 == "Ahsoka Tano" :
        return "The light is the true path"
    if Interrogation_1 == "Ventress" :
        return "Dooku, you traitor!"
    if Interrogation_1 == "Cal_Kestis" :
        return "BD-1, thank you"
    if Interrogation_1 == Captain_Phasma :
        return "I am the fancy one"
    else :
        return "You have chosen your destiny. Continue young one." 
    

        
#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 

Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
the_balance()
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.Narnia
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.other
# 'You have chosen your destiny. Continue young one.'

# %%
#One more test

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.")
    if  Interrogation_1 == "Luke Skywalker" : 
        print("The Chosen One")
    if Interrogation_1 == "Emperor Palpatine" : 
        print("The Dark Side Prevails")
    if Interrogation_1 == "Obi-Wan Kenobi" : 
        return "Hello There!"
    if Interrogation_1 == "Darth Vadar" :
        return "Feel the power of the dark side"
    if Interrogation_1 == "Ahsoka Tano" :
        return "The light is the true path"
    if Interrogation_1 == "Ventress" :
        return "Dooku, you traitor!"
    if Interrogation_1 == "Cal_Kestis" :
        return "BD-1, thank you"
    if Interrogation_1 == Captain_Phasma :
        return "I am the fancy one"
    else :
        return "So you have chosen this individual of fate? I see... Continue young one." 
    

        
#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 

Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.Luke Skywalker
# The Chosen One

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)"


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables. 

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Jedi = ["Luke Skywalker", "Obi-Wan Kenobi", "Ahsoka Tano", "Cal Kestis"]
Sith = ["Emperor Palpatine", "Darth Vadar", "Ventress", "Captain Phasma"]
Luke_Skywalker = Jedi[0]
ObiWan_Kenobi = Jedi[1]
Ahsoka_Tano = Jedi[2]
Cal_Kestis = Jedi[3]
Emperor_Palpatine= Sith[0]
Darth_Vadar= Sith[1]
Ventress= Sith[2]
Captain_Phasma= Sith[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Interrogation_1 = input("Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.")
    if  Interrogation_1 == "Luke Skywalker" : 
        print("The Chosen One")
    if Interrogation_1 == "Emperor Palpatine" : 
        print("The Dark Side Prevails")
    if Interrogation_1 == "Obi-Wan Kenobi" : 
        return "Hello There!"
    if Interrogation_1 == "Darth Vadar" :
        return "Feel the power of the dark side"
    if Interrogation_1 == "Ahsoka Tano" :
        return "The light is the true path"
    if Interrogation_1 == "Ventress" :
        return "Dooku, you traitor!"
    if Interrogation_1 == "Cal_Kestis" :
        return "BD-1, thank you"
    if Interrogation_1 == Captain_Phasma :
        return "I am the fancy one"
    else :
        return "So you have chosen this individual of fate? I see... Continue young one." 
    

        
#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 

Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
# Out:
# Hello Troopers, welcome to the Galactic Survey. My name is Niko Darby and I this is my project for Introduction to Python. Here, you will see a select few iconic names from the Star Wars Universe. By going through a series of questions and answering them, you will be deemed a certain character from the Star Wars Universe. (*NOTICE*: I do not own the rights to any content under the Star Wars brand. The rights belong to Disney, Electronic Arts, and LucasArts. Thank you for your understanding.)
# Who is the most elegant Sith or Jedi? Choose between Luke Skywalker for the Jedi and Emperor Palpatine for the Sith.Emperor Palpatine
# The Dark Side Prevails

# %%
#Now that the I am aware that this Star Wars tutorial works. I will begin the real project. Enjoy.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 

Interrogation_2 = "Who is the most fiesty lightsaber wielder? Choose between Ahsoka Tano or Cal Kestis for the Jedi. For the Sith, choose between Ventress or Darth Vadar."
#Now print your answer below using the_balance("your choice").
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>

# %%
#Next test of the code:

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2()
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
     if  Battle_1 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_1 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section.

the_balance2()
# Out:
#   File "<ipython-input-109-6537efae784a>", line 51
#     def the_balance2()
#                       ^
# SyntaxError: invalid syntax

# %%
#Forgot to add ":"

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
     if  Battle_1 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_1 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section.

the_balance2()
# Out:
#   File "<ipython-input-112-54bed6eeb485>", line 53
#     if  Battle_1 == "lightning stun" :
#     ^
# IndentationError: unexpected indent

# %%
#I will have to find and diminish the indent above.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_1 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_1 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section.

the_balance2()
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-3096db93c19b> in <module>
#      63 #Once you have submitted an answer to the function below. We will proceed to the next section.
#      64
# ---> 65 the_balance2()
#
# <ipython-input-114-3096db93c19b> in the_balance2()
#      51 def the_balance2() :
#      52     Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
# ---> 53     if Battle_1 == "lightning stun" :
#      54         print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
#      55     if Battle_1 == "lightning speed trail" :
#
# NameError: name 'Battle_1' is not defined

# %%
#Forgot to change the battle instance. Will edit now.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section.

the_balance2()
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#This will conclude the demo for now please refer to the print below
print("I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.")
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
# I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#This will conclude the demo for now please refer to the print below
print("I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.")
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.Lightning stun
# I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.

# %%
#I added a new sequence to the story. It is time to test the code.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == Lightning shield :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == Circumference of lightning :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == Shock wimper : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>)
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>)

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 


#This will conclude the demo for now please refer to the print below
print("I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.")
# Out:
#   File "<ipython-input-2-be958d0778df>", line 71
#     if Battle_3 == Lightning shield :
#                                   ^
# SyntaxError: invalid syntax

# %%
#Did not turn the attacks into strings. This was an error on my part.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>)
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>)

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 


#This will conclude the demo for now please refer to the print below
print("I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.")
# Out:
#   File "<ipython-input-4-4171780df989>", line 76
#     print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>)
#                                                                                                                                                                     ^
# SyntaxError: EOL while scanning string literal

# %%
#Did not properly close the string. I will fix this now.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 


#This will conclude the demo for now please refer to the print below
print("I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.")
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Circumference of lightning
# Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>
# I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try Battle_4 == 'Lightning Fury':
        print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
    try Battle_4 == 'Speed of light slash':
        print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
    try Battle_4 == 'Angelic blasphemy' :
        print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except : 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#This will conclude the demo for now please refer to the print below
print("I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.")
# Out:
#   File "<ipython-input-8-1fe708b4522a>", line 88
#     try Battle_4 == 'Lightning Fury':
#                ^
# SyntaxError: invalid syntax

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
    try: 
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
    try: 
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#This will conclude the demo for now please refer to the print below
print("I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.")
# Out:
#   File "<ipython-input-9-a38592387ed4>", line 91
#     try:
#       ^
# SyntaxError: invalid syntax

# %%
#Hmm, there seems to be an invalid syntax with the try-except statement. I must fix it.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#This will conclude the demo for now please refer to the print below
print("I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.")
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.Lightning stun
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Circumference of lightning
# Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
# I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined.
#This will conclude the demo for now please refer to the print below
print("I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.")
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? water
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?shock wimper
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?speed of light slash
# I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.

# %%
# I have concocted a ".csv" file to install into this project. We will begin troubleshooting it from here.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet. 

pd.read_csv('Pileq_XonoRex_File.csv')
pd.sort_index('Pileq_XonoRex_File.csv')
pd.plot(kind= 'bar')
pd.show()

#This will conclude the demo for now please refer to the print below
print("I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.")
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Circumference of lightning
# Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Speed of light slash
# 'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-d39a21a8b77c> in <module>
#     117 #This instance will now transition into examining the data sheet.
#     118
# --> 119 pd.read_csv('Pileq_XonoRex_File.csv')
#     120 pd.sort_index('Pileq_XonoRex_File.csv')
#     121 pd.plot(kind= 'bar')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'Pileq_XonoRex_File.csv' does not exist: b'Pileq_XonoRex_File.csv'

# %%
#It seems as though the '.csv' file is not in my directory. I will have to find a way to transfer it.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()

#It is time to iew the data sheet. 
data = pd.read_csv('Pileq_XonoRex_File.csv')
data.head()
pd.sort_index('Pileq_XonoRex_File.csv')
pd.plot(kind= 'bar')
pd.show()

#This will conclude the demo for now please refer to the print below
print("I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.")
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Circumference of lightning
# Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Speed of light slash
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Condolences
# 'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-231e85f8a2f0> in <module>
#     120
#     121 #It is time to iew the data sheet.
# --> 122 data = pd.read_csv('Pileq_XonoRex_File.csv')
#     123 data.head()
#     124 pd.sort_index('Pileq_XonoRex_File.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'Pileq_XonoRex_File.csv' does not exist: b'Pileq_XonoRex_File.csv'

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()

#It is time to view the data sheet. 
data = pd.read_csv('C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
pd.sort_index(data)
pd.plot(kind= 'bar')
pd.show()
# Out:
#   File "<ipython-input-6-8510a68e75ab>", line 122
#     data = pd.read_csv('C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
#                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
#Made a few edits to the '.csv' file. Let us see if this functions properly.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()

#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
pd.sort_index(data)
pd.plot(kind= 'bar')
pd.show()

#This will conclude the demo for now please refer to the print below
print("I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.")
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?lightning shield
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Speed of light slash
# 'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-6c632c1b28af> in <module>
#     122 data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
#     123 data.head()
# --> 124 pd.sort_index(data)
#     125 pd.plot(kind= 'bar')
#     126 pd.show()
#
# ~\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'sort_index'

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()

#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
pd.plot(kind= 'bar')
pd.show()

#This will conclude the demo for now please refer to the print below
print("I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.")
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Circumference of lightning
# Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Speed of light slash
# 'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-fa9653f60623> in <module>
#     123 data.head()
#     124 data.sort_index()
# --> 125 pd.plot(kind= 'bar')
#     126 pd.show()
#     127
#
# ~\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'plot'

# %%
# Still encountering errors with the '.csv' file. I will continue to fix it.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()

#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data.plot(kind= 'bar')
pd.show()

#This will conclude the demo for now please refer to the print below
print("I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.")
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Speed of light slash
# 'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-872bf8bad704> in <module>
#     124 data.sort_index()
#     125 data.plot(kind= 'bar')
# --> 126 pd.show()
#     127
#     128 #This will conclude the demo for now please refer to the print below
#
# ~\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'show'

# %%
# I may have to utilize some of 'matplotlib' for this '.csv' file.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()

#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data.plot(kind= 'bar')
data.show()

#This will conclude the demo for now please refer to the print below
print("I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.")
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Speed of light slash
# 'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-c626fe61dac1> in <module>
#     124 data.sort_index()
#     125 data.plot(kind= 'bar')
# --> 126 data.show()
#     127
#     128 #This will conclude the demo for now please refer to the print below
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %%
# I have to eradicate the Syntax Error

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()

#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data.plot(kind= 'bar')


#This will conclude the demo for now please refer to the print below
print("I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.")
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Circumference of lightning
# Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Speed of light slash
# 'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# I hope that you enjoyed this demo of 'Universe of Loz: Battle of the Ages'. The full version will release before Friday, December 13th 2019.

# %%
# The chart needs to be edited for conciseness.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()

#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_labels = ('Zon-noZ', 'Oy-Boqa', 'Velocitus X', 'Aetomatus Prime')
data.plot(kind= 'bar')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Circumference of lightning
# Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>

# %%
#Forgot to change the columns. Will fix now.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()

#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_labels = ('Zon-noZ', 'Oy-Boqa', 'Velocitus X', 'Aetomatus Prime')
data.columns = data_labels
data.plot(kind= 'bar')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-4dafc4a9c556> in <module>
#     124 data.sort_index()
#     125 data_labels = ('Zon-noZ', 'Oy-Boqa', 'Velocitus X', 'Aetomatus Prime')
# --> 126 data.columns = data_labels
#     127 data.plot(kind= 'bar')
#     128
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5190         try:
#    5191             object.__getattribute__(self, name)
# -> 5192             return object.__setattr__(self, name, value)
#    5193         except AttributeError:
#    5194             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     688
#     689     def _set_axis(self, axis, labels):
# --> 690         self._data.set_axis(axis, labels)
#     691         self._clear_item_cache()
#     692
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     181             raise ValueError(
#     182                 "Length mismatch: Expected axis has {old} elements, new "
# --> 183                 "values have {new} elements".format(old=old_len, new=new_len)
#     184             )
#     185
#
# ValueError: Length mismatch: Expected axis has 3 elements, new values have 4 elements

# %%
#The chart seems to be zero-indexing. Let's attempt to use a list.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()

#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_labels = [['Zon-noZ', 'Oy-Boqa', 'Velocitus X', 'Aetomatus Prime']]
data.columns = data_labels
data.plot(kind= 'bar')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Speed of light slash
# 'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-f781e93bc253> in <module>
#     124 data.sort_index()
#     125 data_labels = [['Zon-noZ', 'Oy-Boqa', 'Velocitus X', 'Aetomatus Prime']]
# --> 126 data.columns = data_labels
#     127 data.plot(kind= 'bar')
#     128
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5190         try:
#    5191             object.__getattribute__(self, name)
# -> 5192             return object.__setattr__(self, name, value)
#    5193         except AttributeError:
#    5194             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     688
#     689     def _set_axis(self, axis, labels):
# --> 690         self._data.set_axis(axis, labels)
#     691         self._clear_item_cache()
#     692
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     181             raise ValueError(
#     182                 "Length mismatch: Expected axis has {old} elements, new "
# --> 183                 "values have {new} elements".format(old=old_len, new=new_len)
#     184             )
#     185
#
# ValueError: Length mismatch: Expected axis has 3 elements, new values have 4 elements

# %%
#There are four sections, yet they are labelled 0-3 and I cannot assign a name to each number.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()

#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_labels = [['Zon-noZ', 'Oy-Boqa', 'Velocitus X']]
data.columns = data_labels
data.plot(kind= 'bar')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Speed of light slash
# 'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>

# %%
#This is not what I wanted. I will perform further alterations.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()

#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data.plot(kind= 'bar')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Circumference of lightning
# Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Speed of light slash
# 'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()

#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data.title('Pileqs Data for Domination')
data.xlabel('Planets of Interest')
data.plot(kind= 'bar')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-6310ed1863b9> in <module>
#     123 data.head()
#     124 data.sort_index()
# --> 125 data.title('Pileqs Data for Domination')
#     126 data.xlabel('Planets of Interest')
#     127 data.plot(kind= 'bar')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'title'

# %%
#May have made a typo.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print("Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print("Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print("Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print("Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()

#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
plt.title('Pileqs Data for Domination')
plt.xlabel('Planets of Interest')
data.plot(kind= 'bar')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-6f5e634e8443> in <module>
#     123 data.head()
#     124 data.sort_index()
# --> 125 plt.title('Pileqs Data for Domination')
#     126 plt.xlabel('Planets of Interest')
#     127 data.plot(kind= 'bar')
#
# AttributeError: module 'matplotlib' has no attribute 'title'

# %%
# Made a few general edits.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt
import colorama 
from colorama import Fore, Style

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print("Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print("Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print("Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()

#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()

#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
plt.xlabel('Planets of Interest')
data.plot(kind= 'bar')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-86fa28391014> in <module>
#     125 data.head()
#     126 data.sort_index()
# --> 127 plt.xlabel('Planets of Interest')
#     128 data.plot(kind= 'bar')
#     129
#
# AttributeError: module 'matplotlib' has no attribute 'xlabel'

# %%
#The color change is similar to a virus infecting everything. This will need to be fixed.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt
import colorama 
from colorama import Fore, Style

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()

#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data.plot(kind= 'bar')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.Lightning stun
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>

# %%
#Will retry

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt
import colorama 
from colorama import Fore, Style

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input("The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input("Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>" 
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input("Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print("Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print("Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print("Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return ("Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
                
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input("'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print("'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print("'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print("'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return ("Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()

#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input("'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print("'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print("Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print("'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return ("Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()

#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data.plot(kind= 'bar')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt
import colorama 
from colorama import Fore, Style

#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning Fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data.plot(kind= 'bar')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt
import colorama 
from colorama import Fore, Style
print(Fore.GOLD + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data.plot(kind= 'bar')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-d52a7694fb20> in <module>
#      14 import colorama
#      15 from colorama import Fore, Style
# ---> 16 print(Fore.GOLD + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
#      17 #The necessary packages have been uploaded. It is now time to define some general terms.
#      18 Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
#
# AttributeError: 'AnsiFore' object has no attribute 'GOLD'

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt
import colorama 
from colorama import Fore, Style
print(Fore.PURPLE + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data.plot(kind= 'bar')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-802a353ec352> in <module>
#      14 import colorama
#      15 from colorama import Fore, Style
# ---> 16 print(Fore.PURPLE + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
#      17 #The necessary packages have been uploaded. It is now time to define some general terms.
#      18 Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
#
# AttributeError: 'AnsiFore' object has no attribute 'PURPLE'

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data.plot(kind= 'bar')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>

# %%
#A few errors in the color schematic need to be edited. The chart will be focused on again soon.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data.plot(kind= 'bar')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>

# %%
#Time for another test with an updated import of matplotlib

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
plt.title('Pileq Domination Statistics')
plt.xlabel('Planets of Interest')
data.plot(kind= 'bar')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>

# %%
#Made a few edits to the chart. Time to run it!

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()

data.plot(kind= 'bar', x= 'Planets of Interest', y= 'Counts in Billions')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Planets of Interest'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-2902e9918229> in <module>
#     128 data.sort_index()
#     129
# --> 130 data.plot(kind= 'bar', x= 'Planets of Interest', y= 'Counts in Billions')
#     131
#     132
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     757                 if is_integer(x) and not data.columns.holds_integer():
#     758                     x = data_cols[x]
# --> 759                 elif not isinstance(data[x], ABCSeries):
#     760                     raise ValueError("x must be a label or position")
#     761                 data = data.set_index(x)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Planets of Interest'

# %%
#Made a typo in the code format

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()

data.plot(kind= 'bar', x= 'Planets_of_Interest', y= 'Counts_by_Billions')


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Planets_of_Interest'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-28560a99cd50> in <module>
#     128 data.sort_index()
#     129
# --> 130 data.plot(kind= 'bar', x= 'Planets_of_Interest', y= 'Counts_by_Billions')
#     131
#     132
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     757                 if is_integer(x) and not data.columns.holds_integer():
#     758                     x = data_cols[x]
# --> 759                 elif not isinstance(data[x], ABCSeries):
#     760                     raise ValueError("x must be a label or position")
#     761                 data = data.set_index(x)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Planets_of_Interest'

# %%
# Additional chart troubleshooting

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. 
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.show()


#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-4509cd26a09f> in <module>
#     130 data_plot.set_xlabel('Planets of Interest')
#     131 data_plot.set_ylabel('Counts by Billions')
# --> 132 data_plot.show()
#     133
#     134
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'

# %%
#Still attempting to get the 0-3 on the x-axis to words. I will attempt some '.loc' functions.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data1 = data.loc[['Zon-noZ','Oy-Boqa','Velocitus X','Aetomatus Prime']]
data1.sort_index()
data_plot= data1.plot(kind= 'bar')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')



#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-2f30303c2308> in <module>
#     126 data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
#     127 data.head()
# --> 128 data1 = data.loc[['Zon-noZ','Oy-Boqa','Velocitus X','Aetomatus Prime']]
#     129 data1.sort_index()
#     130 data_plot= data1.plot(kind= 'bar')
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1837                     raise ValueError("Cannot index with multidimensional key")
#    1838
# -> 1839                 return self._getitem_iterable(key, axis=axis)
#    1840
#    1841             # nested tuple slicing
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1131         else:
#    1132             # A collection of keys
# -> 1133             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1134             return self.obj._reindex_with_indexers(
#    1135                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [Index(['Zon-noZ', 'Oy-Boqa', 'Velocitus X', 'Aetomatus Prime'], dtype='object')] are in the [index]"

# %%
#Will need to re-run to fix the errors received.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data1 = data[['Zon-noZ','Oy-Boqa','Velocitus X','Aetomatus Prime']]
data1.sort_index()
data_plot= data1.plot(kind= 'bar')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')



#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-640572a3c940> in <module>
#     126 data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
#     127 data.head()
# --> 128 data1 = data[['Zon-noZ','Oy-Boqa','Velocitus X','Aetomatus Prime']]
#     129 data1.sort_index()
#     130 data_plot= data1.plot(kind= 'bar')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [Index(['Zon-noZ', 'Oy-Boqa', 'Velocitus X', 'Aetomatus Prime'], dtype='object')] are in the [columns]"

# %%
#Time for another test

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data1 = data.set_index(['Zon-noZ','Oy-Boqa','Velocitus X','Aetomatus Prime'])
data1.sort_index()
data_plot= data1.plot(kind= 'bar')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-5e6fabbd62b9> in <module>
#     126 data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
#     127 data.head()
# --> 128 data1 = data.set_index(['Zon-noZ','Oy-Boqa','Velocitus X','Aetomatus Prime'])
#     129 data1.sort_index()
#     130 data_plot= data1.plot(kind= 'bar')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['Zon-noZ', 'Oy-Boqa', 'Velocitus X', 'Aetomatus Prime'] are in the columns"

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data1 = data.set_index('Zon-noZ','Oy-Boqa','Velocitus X','Aetomatus Prime')
data1.sort_index()
data_plot= data1.plot(kind= 'bar')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')



#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-e5f02a88557a> in <module>
#     126 data = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
#     127 data.head()
# --> 128 data1 = data.set_index('Zon-noZ','Oy-Boqa','Velocitus X','Aetomatus Prime')
#     129 data1.sort_index()
#     130 data_plot= data1.plot(kind= 'bar')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4362         4 16     10  2014    31
#    4363         """
# -> 4364         inplace = validate_bool_kwarg(inplace, "inplace")
#    4365         if not isinstance(keys, list):
#    4366             keys = [keys]
#
# ~\Anaconda3\lib\site-packages\pandas\util\_validators.py in validate_bool_kwarg(value, arg_name)
#     234         raise ValueError(
#     235             'For argument "{arg}" expected type bool, received '
# --> 236             "type {typ}.".format(arg=arg_name, typ=type(value).__name__)
#     237         )
#     238     return value
#
# ValueError: For argument "inplace" expected type bool, received type str.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data0 = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data1= pd.DataFrame({"planet names":['Zon-noZ','Oy-Boqa','Velocitus X','Aetomatus Prime'})
data1.head()
data1.sort_index()
data_plot= data1.plot(kind= 'bar')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')



#This will conclude the demo for now please refer to the print below
# Out:
#   File "<ipython-input-56-bbe395e1d7d7>", line 127
#     data1= pd.DataFrame({"planet names":['Zon-noZ','Oy-Boqa','Velocitus X','Aetomatus Prime'})
#                                                                                             ^
# SyntaxError: invalid syntax

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data0 = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data1= pd.DataFrame({"planet names":['Zon-noZ','Oy-Boqa','Velocitus X','Aetomatus Prime']})
data1.head()
data1.sort_index()
data_plot= data1.plot(kind= 'bar')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')



#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-fcd20a3d3769> in <module>
#     128 data1.head()
#     129 data1.sort_index()
# --> 130 data_plot= data1.plot(kind= 'bar')
#     131 data_plot.set_xlabel('Planets of Interest')
#     132 data_plot.set_ylabel('Counts by Billions')
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     277     def generate(self):
#     278         self._args_adjust()
# --> 279         self._compute_plot_data()
#     280         self._setup_subplots()
#     281         self._make_plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     412         # no non-numeric frames or series allowed
#     413         if is_empty:
# --> 414             raise TypeError("no numeric data to plot")
#     415
#     416         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
#Another test.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data0 = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data1= pd.DataFrame({"planet names":['Zon-noZ','Oy-Boqa','Velocitus X','Aetomatus Prime'], "count": np.randon.randint(0,3000, size=4)})
data1.head()
data1.sort_index()
data_plot= data1.plot(kind= 'bar')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')



#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-b0b59a4ce4a5> in <module>
#     125 #It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
#     126 data0 = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
# --> 127 data1= pd.DataFrame({"planet names":['Zon-noZ','Oy-Boqa','Velocitus X','Aetomatus Prime'], "count": np.randon.randint(0,3000, size=4)})
#     128 data1.head()
#     129 data1.sort_index()
#
# AttributeError: module 'numpy' has no attribute 'randon'

# %%
# Made a typo. Will retry now.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data0 = pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data1= pd.DataFrame({"planet names":['Zon-noZ','Oy-Boqa','Velocitus X','Aetomatus Prime'], "count": np.random.randint(0,3000, size=4)})
data1.head()
data1.sort_index()
data_plot= data1.plot(kind= 'bar')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')



#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# Text(0, 0.5, 'Counts by Billions')

# %%
#This method seems to have obliterated my chart. Time to restart the troubleshooting.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data['Zon-noZ':'Aetomatus Prime']
data_plot= data.plot(kind= 'bar'
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')



#This will conclude the demo for now please refer to the print below
# Out:
#   File "<ipython-input-63-69b02b622229>", line 131
#     data_plot.set_xlabel('Planets of Interest')
#             ^
# SyntaxError: invalid syntax

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar'
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')



#This will conclude the demo for now please refer to the print below
# Out:
#   File "<ipython-input-64-e343e2a48eef>", line 130
#     data_plot.set_xlabel('Planets of Interest')
#             ^
# SyntaxError: invalid syntax

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data['Zon-noZ':'Aetomatus Prime']
data_plot= data.plot(kind= 'bar')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')



#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-f92e6c81c35c> in <module>
#     127 data.head()
#     128 data.sort_index()
# --> 129 data['Zon-noZ':'Aetomatus Prime']
#     130 data_plot= data.plot(kind= 'bar')
#     131 data_plot.set_xlabel('Planets of Interest')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2959
#    2960         # Do we have a slicer (on rows)?
# -> 2961         indexer = convert_to_index_sliceable(self, key)
#    2962         if indexer is not None:
#    2963             return self._slice(indexer, axis=0)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in convert_to_index_sliceable(obj, key)
#    2356     idx = obj.index
#    2357     if isinstance(key, slice):
# -> 2358         return idx._convert_slice_indexer(key, kind="getitem")
#    2359
#    2360     elif isinstance(key, str):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _convert_slice_indexer(self, key, kind)
#    3188             if self.is_integer() or is_index_slice:
#    3189                 return slice(
# -> 3190                     self._validate_indexer("slice", key.start, kind),
#    3191                     self._validate_indexer("slice", key.stop, kind),
#    3192                     self._validate_indexer("slice", key.step, kind),
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _validate_indexer(self, form, key, kind)
#    5069             pass
#    5070         elif kind in ["iloc", "getitem"]:
# -> 5071             self._invalid_indexer(form, key)
#    5072         return key
#    5073
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _invalid_indexer(self, form, key)
#    3338             "cannot do {form} indexing on {klass} with these "
#    3339             "indexers [{key}] of {kind}".format(
# -> 3340                 form=form, klass=type(self), key=key, kind=type(key)
#    3341             )
#    3342         )
#
# TypeError: cannot do slice indexing on <class 'pandas.core.indexes.range.RangeIndex'> with these indexers [Zon-noZ] of <class 'str'>

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')



#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# Text(0, 0.5, 'Counts by Billions')

# %%
#Another test utilizing the rows and columns inputs.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
rows = ['Zon-noZ','Oy-Boqa','Velocitus X', 'Aetomatus Prime']
columns = ['Xono-Rex Potential (In billions)', 'Chance of Domination (Percentage)']
data.loc[rows,columns]
data_plot= data.plot(kind= 'bar')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')



#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-3dddf14d74e7> in <module>
#     129 rows = ['Zon-noZ','Oy-Boqa','Velocitus X', 'Aetomatus Prime']
#     130 columns = ['Xono-Rex Potential (In billions)', 'Chance of Domination (Percentage)']
# --> 131 data.loc[rows,columns]
#     132 data_plot= data.plot(kind= 'bar')
#     133 data_plot.set_xlabel('Planets of Interest')
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     812         # ugly hack for GH #836
#     813         if self._multi_take_opportunity(tup):
# --> 814             return self._multi_take(tup)
#     815
#     816         # no shortcut needed
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _multi_take(self, tup)
#     867         d = {
#     868             axis: self._get_listlike_indexer(key, axis)
# --> 869             for (key, axis) in zip(tup, o._AXIS_ORDERS)
#     870         }
#     871         return o._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in <dictcomp>(.0)
#     867         d = {
#     868             axis: self._get_listlike_indexer(key, axis)
# --> 869             for (key, axis) in zip(tup, o._AXIS_ORDERS)
#     870         }
#     871         return o._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [Index(['Zon-noZ', 'Oy-Boqa', 'Velocitus X', 'Aetomatus Prime'], dtype='object')] are in the [index]"

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
print(data.head())
data.sort_index()
rows = ['Zon-noZ','Oy-Boqa','Velocitus X', 'Aetomatus Prime']
columns = ['Xono-Rex Potential (In billions)', 'Chance of Domination (Percentage)']
data.loc[rows,columns]
data_plot= data.plot(kind= 'bar')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')



#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
#
#            Column1  Xono-Rex Potential (In billions)  \
# 0          Zon-noZ                               900
# 1          Oy-Boqa                               878
# 2      Velocitus X                               956
# 3  Aetomatus Prime                              1200
#
#    Chance of Domination (Percentage)
# 0                               1500
# 1                               1100
# 2                               1023
# 3                               2098
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-7a03a61dfa48> in <module>
#     129 rows = ['Zon-noZ','Oy-Boqa','Velocitus X', 'Aetomatus Prime']
#     130 columns = ['Xono-Rex Potential (In billions)', 'Chance of Domination (Percentage)']
# --> 131 data.loc[rows,columns]
#     132 data_plot= data.plot(kind= 'bar')
#     133 data_plot.set_xlabel('Planets of Interest')
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     812         # ugly hack for GH #836
#     813         if self._multi_take_opportunity(tup):
# --> 814             return self._multi_take(tup)
#     815
#     816         # no shortcut needed
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _multi_take(self, tup)
#     867         d = {
#     868             axis: self._get_listlike_indexer(key, axis)
# --> 869             for (key, axis) in zip(tup, o._AXIS_ORDERS)
#     870         }
#     871         return o._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in <dictcomp>(.0)
#     867         d = {
#     868             axis: self._get_listlike_indexer(key, axis)
# --> 869             for (key, axis) in zip(tup, o._AXIS_ORDERS)
#     870         }
#     871         return o._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [Index(['Zon-noZ', 'Oy-Boqa', 'Velocitus X', 'Aetomatus Prime'], dtype='object')] are in the [index]"

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
print(data.head())
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])



#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
#
#            Column1  Xono-Rex Potential (In billions)  \
# 0          Zon-noZ                               900
# 1          Oy-Boqa                               878
# 2      Velocitus X                               956
# 3  Aetomatus Prime                              1200
#
#    Chance of Domination (Percentage)
# 0                               1500
# 1                               1100
# 2                               1023
# 3                               2098
# [Text(0, 0, 'Zon-noZ'),
#  Text(0, 0, 'Oy-Boqa'),
#  Text(0, 0, 'Velocitus X'),
#  Text(0, 0, 'Aetomatus Prime')]

# %%
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])



#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# [Text(0, 0, 'Zon-noZ'),
#  Text(0, 0, 'Oy-Boqa'),
#  Text(0, 0, 'Velocitus X'),
#  Text(0, 0, 'Aetomatus Prime')]

# %%
#A fresh code is ready to execute.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 = 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. There chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 = 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 = 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now please refer to the print below
# Out:
#   File "<ipython-input-73-70bdd560c5cc>", line 140
#     if Interrogation_2 = 'Report the news':
#                        ^
# SyntaxError: invalid syntax

# %%
#There is a SyntaxError. I will fix it now.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 == 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. There chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 == 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 == 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
#
# 'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?Brag about battle
# 'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])
input(data_plot)


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 == 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. There chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 == 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 == 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
#
# AxesSubplot(0.125,0.125;0.775x0.755)all
# 'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?Troll
# Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>

# %%
#The plot needs to be shown before the final function. I must fix this.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])
plt.show()


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 == 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. There chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 == 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 == 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now please refer to the print below
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# 'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?Report the news
# 'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. There chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])
plt.show()


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 == 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 == 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 == 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now. Thank you for playing.
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Air
# Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Shock wimper
# Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# 'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?Brag about battle
# 'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])
plt.show()


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 == 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 == 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 == 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now. Thank you for playing.
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Lightning
# Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# 'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?Brag about battle
# 'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])
plt.show()


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 == 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 == 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 == 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now. Thank you for playing.
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Circumference of lightning
# Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Condolences
# 'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>
# 'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?Troll
# Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])
plt.show()


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 == 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 == 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 == 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now. Thank you for playing.
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# 'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?Report the news
# 'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])
plt.show()


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 == 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 == 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 == 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now. Thank you for playing.
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Lightning
# Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Circumference of lightning
# Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Speed of light slash
# 'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Meditate
# Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>
# 'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?Brag about battle
# 'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])
plt.show()


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 == 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 == 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 == 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now. Thank you for playing.
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Circumference of lightning
# Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# 'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?Brag about battle
# 'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])
plt.show()


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 == 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 == 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 == 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now. Thank you for playing.
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Circumference of lightning
# Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# 'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?Report the news
# 'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])
plt.show()


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 == 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 == 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 == 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now. Thank you for playing.
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>

# %%
#For the past few days I have randomly encountered the error of <Figure size 640x480 with 1 Axes> without the actual figure showing. After observing similar issues on StackOverflow, I discovered that I will have to use magics in order to fix this problem. I will attempt to do a few now with the matplotlib package.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
# %matplotlib notebook
# %matplotlib notebook
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])
plt.show()


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 == 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 == 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 == 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now. Thank you for playing.
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Circumference of lightning
# Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Focus
# 'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>
# <img src="data:image/png;base64,..." width="640">
# 'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?Report the news
# 'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>

# %%
# it seems as though the %matplotlib notebook magics leads to a glitch in the presentation of the graph. I will have to fix this.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])
plt.show()


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 == 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 == 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 == 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now. Thank you for playing.
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Circumference of lightning
# Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Condolences
# 'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>
# 'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?Report the news
# 'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>

# %%
#By simply and strictly using the %matplotlib inline magics, I was able to prevent the bug from occurring. I will attempt five(5) more executions to assure its' efficiency.

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])
plt.show()


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 == 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 == 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 == 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now. Thank you for playing.
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Lightning
# Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Speed of light slash
# 'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Meditate
# Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>
# 'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?Brag about battle
# 'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])
plt.show()


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 == 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 == 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 == 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now. Thank you for playing.
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Air
# Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Circumference of lightning
# Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Speed of light slash
# 'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Condolences
# 'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>
# 'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?Report the news
# 'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])
plt.show()


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 == 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 == 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 == 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now. Thank you for playing.
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.lightning stun
# Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Angelic blasphemy
# 'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Condolences
# 'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>
# 'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?Report the news
# 'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>

# %%
#First we will begin with an introduction. I will concoct a string that will introduce all users to the project. 
Introduction = "Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy."


#Now for a test of the string. Indubitably, this will be inserted into the Notebook and Tests folder for further examination. 
print(Introduction)

#The Introduction has been printed. Now it is time to construct the questions and define different variables.  

#Let us begin by importing the necessary packages for this project. Some may or may not be used. 
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import colorama 
from colorama import Fore, Style
print(Fore.YELLOW + "NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!")
print(Style.RESET_ALL)
#The necessary packages have been uploaded. It is now time to define some general terms. 
Zerxocia = ("Galiuto", "Rev-Tyz", "Commander Vizil", "Fala-To")
Pileqs = ("Emperor Kret-Po", "Wujo-Bax", "Horschux", "Captain Phantox")
Galiuto = Zerxocia[0]
Rev_Tyz = Zerxocia[1]
Commander_Vizil = Zerxocia[2]
Fala_To = Zerxocia[3]
Emperor_Kret_Po= Pileqs[0]
Wujo_Bax= Pileqs[1]
Horschux= Pileqs[2]
Captain_Phantox= Pileqs[3]

#The above lists of strings will be of utmost importance in the near furture. 
#It is now time to construct a function that will be useful. 
def the_balance() :
    Battle_1 = input(Fore.BLUE + "The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? ")
    if  Battle_1 == "Fire" : 
        print(Fore.RED + "Horschux: Chuckles, fool, I am immune to fire. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_1 == "Air" : 
        print(Fore.YELLOW + "Horschux: Gahh! The wind is absorbing my fire, what is this force! <Horschux loses 25% of health>")
    if Battle_1 == "Water" : 
        print(Fore.GREEN + "Horschux: Impossible, nooooo!!! <You have defeated Horschux>")
    if Battle_1 == "Lightning" :
        print(Fore.YELLOW + "Horschux: Such power, this is infallible! <Horschux loses 75% of health and retreats>") 

    else :
        return "Galiuto: I don't feel like fighting. I am leaving now. <Departs from quarrel>" 
    

#Since the function "the_balance()" is now created. The rest of the code can be concocted. Now print your answer below using the_balance()'s answer input once the code is executed.

#Here is my sample answer: 

the_balance() 
print(Style.RESET_ALL)

#It is now time for the next question. 
def the_balance2() :
    Battle_2 = input(Fore.BLUE + "Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.")
    if Battle_2 == "lightning stun" : 
        print(Fore.GREEN + "Captain Phantox: I cannot move, what is this? I can feel the lightning going through my cortices! *Fades away* <You have defeated Captain Phantox>")
    if Battle_2 == "lightning speed trail" : 
        print(Fore.RED + "Captain Phantox: A trail? Hmph. Take this! <You have been defeated. Please re-execute the code.>")
    if Battle_2 == "evasive counter maneuvers" : 
        print(Fore.GREEN + "Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>")
    else :
        return (Fore.YELLOW + "Rev-Tyz: I am abandoning this battle *Speeds away* <Departs from quarrel>")
    

#Once you have submitted an answer to the function below. We will proceed to the next section. To execute this sequence of the game simply type: the_balance2()

the_balance2()
print(Style.RESET_ALL)
#Now it is time to transition to the next part of the project. One more function will be created and then more techniques will be incorporated in into the project. 

def balance_3() : 
    Battle_3 = input(Fore.BLUE + "Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?")
    if Battle_3 == "Lightning shield" :
        print(Fore.GREEN + "Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Circumference of lightning" :
        print(Fore.GREEN + "Captain Phantox: Such power! My warps are unable to surpass the speed of light. I will defeat you! <You have succeeded in blocking Captain Phantox's warping strike>")
    if Battle_3 == "Shock wimper" : 
        print(Fore.RED + "Captain Phantox: *Chuckles* You wimper in fear with tears of electricity? Pathetic. *Warping blow* <You have been defeated. Please re-execute the code.>")
    else : 
        return (Fore.YELLOW + "Rev-Tyz: Another attack? I'm getting out of here. *Speeds away* <Departs from quarrel>")

#It is now time to execute this function. Please execute: balance_3() below. 

balance_3()
print(Style.RESET_ALL)
#The if-then functions compilation is now complete. Now it is time to initiate the try-except + if-then functions compilation. 

def balance_4() : 
    Battle_4 = input(Fore.BLUE + "'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?")
    try: 
        if Battle_4 == 'Lightning fury':
            print(Fore.GREEN + "'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Speed of light slash':
            print(Fore.GREEN + "'An instance of pain, you shall endure.'Rev-Tyz whispers as he strikes down Captain Phantox. <Captain Phantox was hit with a powerful blast and is wounded>")
     
        if Battle_4 == 'Angelic blasphemy' :
            print(Fore.GREEN + "'Witness a blinding light of defeat' Rev-Tyz stated as he blinded the entire area with lightning strikes. <Captain Phantox was hit with a powerful blast and is wounded>")
    except: 
         return (Fore.YELLOW + "Rev-Tyz: I am too lazy. I'm getting out of here. *Speeds away* <Departs from quarrel>")
        
#Now that the try-except statement has been completed. Another function must be created. To execute the function above type: balance_4().

balance_4()
print(Style.RESET_ALL)
#The try-except and if-statements have been combined. For the next section, a ".csv" file will be converted into a chart for a more interactive session after an additional function. 

def balance_5(): 
    Interrogation_1 = input(Fore.BLUE + "'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?")
    try: 
        if Interrogation_1 == 'Condolences':
            print(Fore.GREEN + "'You were a worthy opponent Phantox. Rest well.' Rev-Tyz uttered as he began to examine the data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Meditate': 
            print(Fore.GREEN + "Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>")
        if Interrogation_1 == 'Focus': 
            print(Fore.GREEN + "'Alas, I have obtained the data sheet of the Pileqs. Now I can determine which planets they plan to conquer next. But first I must decipher it. Hmm...' Rev-Tyz stated intelligently. <You can now examine the data sheet>")
    except: 
        return (Fore.YELLOW + "Rev-Tyz: Welp, he's gone. I am going to sleep.")
#This instance will now transition into examining the data sheet after executing the function.

balance_5()
print(Style.RESET_ALL)
#It is time to view the data sheet. The name data will be the DataFrame and it will be converted into a chart that the player can examine.
data= pd.read_csv(r'C:\Users\admin\Documents\Pileq_XonoRex_File.csv')
data.head()
data.sort_index()
data_plot= data.plot(kind= 'bar', title= 'Pileq Domination Statistics')
data_plot.set_xlabel('Planets of Interest') 
data_plot.set_ylabel('Counts by Billions')
data_plot.set_xticklabels(data['Column1'])
plt.show()


#The data sheet has been constructed and now the story can continue. 

def balance_6():
    Interrogation_2 = input(Fore.BLUE + "'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?")
    try:
        if Interrogation_2 == 'Report the news':
            print(Fore.GREEN + "'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>")
        if Interrogation_2 == 'Brag about battle':
            print(Fore.GREEN + "'Members of Zerxocia, I have defeated Captain Phantox. According to the files I procured from his remnants, he was one of the most powerful members of the Pileqs. *Chuckles* Also, I have the data sheet of the Pileqs and they are becoming too powerful for us to handle. Their statistics for conquering the universe are infallible!' Rev-Tyz stated in a pompous manner. < You have completed this chapter>")
        if Interrogation_2 == 'Troll':
            print(Fore.RED + "Beep bop boop, all members of Zerxocia. Beep bop, are you there? Beep boop *End transmission* <You have been defeated. Please re-execute the code>")
    except: 
        return (Fore.YELLOW + "'Rev-Tyz: I'm bored. Time to rest.'")
#This function has been completed. Now it is time to execute it. 
balance_6()
print(Style.RESET_ALL)
#This will conclude the demo for now. Thank you for playing.
# Out:
# Hello Warriors. Welcome to 'Universe of Loz: Battle of the Ages'. Here you will be introduced to a band of heroic warriors known as the Zerxocia. The Zerxocia's arch nemesis, the Pileqs, have decided to begin their conquest of the Universe of Loz. Thus far, the Pileqs have raided several planets for their gold-like substance called 'Xono-rex'. Proceeding each raid, the Pileqs would destroy each planet and insert the Xono-rex into their super-ship, called the Lone-King, to power it. The Lone-King is said to be able to destroy two universes with one blast of its' omega-cannon. It is up to the Zerxocia to stop the Pileqs from obtaining Xono-rex and destroying planets in order to save both their own universe and those surrounding. My name is Niko Darby and I am the creator of this adventure, the overseer of the Universe of Loz. Enjoy.
# NOTE TO PLAYERS: Be certain to answer each scenario in the exact spelling and format as provided. Have a grand adventure!
#
# The Great war for the universe of Loz has begun. Galiuto, the leader of the Zerxocia, expeditiously travels to the planet of Zon-noZ to battle Horschux. Horschux is a member of the Pileqs and a demon-warrior that has the power of fire. He has discovered a cache of Xono-rex and plans to procure it all and destroy the planet of Zon-noZ. Galiuto is an expert in all elemental powers.Galiuto's ship lands in Bun-nuB forest where Horschux awaits him with his arsenal. Galiuto exits his ship and confronts Horschux. In order to defeat Horschux, the master of fire, which element should Galiuto use to defeat Horschux? Air, Fire, Water, or Lightning? Water
# Horschux: Impossible, nooooo!!! <You have defeated Horschux>
#
# Horschux has been defeated by Galiuto. Galiuto meditates and watches over his companions with his stream of minds ability. Rev-Tyz is currently on Planet Oy-Boqa fighting Captain Phantox, who has found a mountain filled with Xono-rex. Phantox has the ability to warp whereas Rev-Tyz has super speed and lightning powers. How should Rev-Tyz defeat Phantox? Choose between lightning stun, lightning speed trail, or evasive counter maneuvers.evasive counter maneuvers
# Captain Phantox: You have dodged and countered all of my attacks. I have been defeated. This is enlightening *Fades away* <You have defeated Captain Phantox>
#
# Rev-Tyz believed that Captain Phantox was defeated and began to walk away slowly. Alas, there was a rumble in Rev-Tyz's senses. Captain Phantox reappeared stronger than ever. His warping abilities were immeasurable. 'Did you really believe that it would be that easy to defeat me? I am called 'Captain' for a reason. I will extract this mountain of its Xono-rex right after I defeat you!' exclamored Captain Phantox. Rev-Tyz stared at the all-powerful Captain Phantox in awe and assumed his fighting position. Captain Phantox initiated his warping strike, yet Rev-Tyz developed a maneuver fast. Which attack will you use? Lightning shield, Circumference of lightning, or Shock wimper?Lightning shield
# Captain Phantox: Gah! Your shield is immensely powerful, I will need to instantaneously develop a new maneuver <You have succeeded in blocking Captain Phantox's warping strike>
#
# 'You must not know that I am Rev-Tyz, the second in command of the Zerxocia. It is quite unfortunate that your attacks are failing. I really expected for scum like you with the title 'Captain' to be a challenge... But you are just a waste of my time.' Rev-Tyz exclamors in a cocky manner. Lightning began to surround Rev-Tyz's body, creating a powerful aura. 'Let us fight til' the end then, second commander Rev-Tyz. The Pileqs will control life as you know it! *Chuckles*'Captain Phantox stated bravely. Rev-Tyz charges in with one of his most powerful attacks. Which will you use? Lightning fury, Speed of light slash, or Angelic blasphemy?Lightning fury
# 'A thousand fists of lightning to your fragile soul!!' Rev-Tyz stated softly yet arrogantly. <Captain Phantox was hit with a powerful blast and is wounded>
#
# 'Your power is rather impressive, Rev-Tyz.' Captain Phantox stated while holding his fatal wound.'As an honorable warrior, I will give you this data sheet that contains the information of the Pileqs. This is my first and last act of kindness and my redemption. Farewell.' Captain Phantox perished to dust and Rev-Tyz obtained the data sheet. What will you do now? Condolences, Meditate, or Focus?Meditate
# Good riddance. Now I must rest and then examine this data sheet.' <You can now examine the data sheet>
# 'This is madness. The Pileqs have such extraordinary data. They will be able to conquer the universe instantaneously. I need to report this to the Zerxocia headquarters.' Rev-Tyz stated after examining the data. He took out his communicator and began his transmission. What will you say? Report the news, Brag about battle, or Troll?Report the news
# 'Attention members of Zerxocia, I have obtained the data sheet of the Pileqs. Their chances of conquering the universe are infallible. We must bring the war to them or life in the Universe of Loz is done for.' Rev-Tyz stated urgently. <You have completed this chapter>

# %%
#Excellent, after five(5) tries the chart appeared without any errors. The bug has been patched properly.
